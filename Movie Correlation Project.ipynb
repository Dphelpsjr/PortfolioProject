# %%
# First let's import the packages we will use in this project
# You can do this all now or as you need them

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusts the configuration of the plots we will create



# Read the data
df = pd.read_csv(r'C:\Users\derri\Downloads\movies.csv')

# %%
# let's take a look at the data

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing))) #print('{} - {}%'.format(col, round(pct_missing*100))) gives different answer
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Data Types for our columns

print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['budget'] = df['budget'].fillna(0) # Convert nan/null to 0
df['budget'] = df['budget'].astype(int)
df['gross'] = df['gross'].fillna(0)
df['gross'] = df['gross'].astype(int)

# %%
display(df)
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# 5                                    Friday the 13th          R     Horror
# 6                                 The Blues Brothers          R     Action
# 7                                        Raging Bull          R  Biography
# 8                                        Superman II         PG     Action
# 9                                    The Long Riders          R  Biography
# 10                             Any Which Way You Can         PG     Action
# ...

# %%
# Create correct year column
# 'released' is in June 13, 1980 (United States) format instead of time stamped format. 

df['year_correct'] = df['released'].astype(str).str.extract(r',.(\b\d+)') # this code extracts year without me needing to convert into 'released' into different format

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Drop any duplicates

# Can df['company'].drop_duplicates().sort_values(ascending=False) also

df.drop_duplicates()
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# 5                                    Friday the 13th          R     Horror
# 6                                 The Blues Brothers          R     Action
# 7                                        Raging Bull          R  Biography
# 8                                        Superman II         PG     Action
# 9                                    The Long Riders          R  Biography
# 10                             Any Which Way You Can         PG     Action
# ...

# %%
# Order our Data a little bit to see in descending order

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                                name     rating      genre  \
# 6663     Star Wars: Episode VII - The Force Awakens      PG-13     Action
# 7244                         Avengers: Infinity War      PG-13     Action
# 7480                                  The Lion King         PG  Animation
# 6653                                 Jurassic World      PG-13     Action
# 6043                                   The Avengers      PG-13     Action
# 6646                                      Furious 7      PG-13     Action
# 7494                                      Frozen II         PG  Animation
# 6644                        Avengers: Age of Ultron      PG-13     Action
# 7247                                  Black Panther      PG-13     Action
# 5845   Harry Potter and the Deathly Hallows: Part 2      PG-13  Adventure
# 7075        Star Wars: Episode VIII - The Last Jedi      PG-13     Action
# 7271                 Jurassic World: Fallen Kingdom      PG-13     Action
# ...

# %%
# Can use pd.set_option('display.max_rows', None) to see max rows

# %%
# Drop any duplicates

df['company'].drop_duplicates().sort_values(ascending=False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 6412                             iDeal Partners Film Fund
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 524                             Zupnik-Curtis Enterprises
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 6222                        Zentropa International Norway
# 3368                              Zentropa Entertainments
# 535                                  Zenith Entertainment
# 5180                                      Zazen Produções
# 3193                                          ZapPictures
# ...

# %%
# Are there any Outliers?

df.boxplot(column=['gross'])

# %%
sns.regplot(x="gross", y="budget", data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})

# %%
sns.regplot(x="score", y="gross", data=df, scatter_kws={"color": "red"}, line_kws={"color":"blue"})

# %%
# Correlation Matrix between all numeric columns
# Using different methods

df.corr(method ='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.256331  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.169406  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.573889  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.687124  0.269510
# gross    0.256331  0.169406  0.573889  0.687124  1.000000  0.204177
# runtime  0.120811  0.399451  0.309212  0.269510  0.204177  1.000000

# %%
df.corr(method ='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.331465  0.209304  0.215943  0.097184
# score    0.067652  1.000000  0.300115 -0.005194  0.089155  0.283611
# votes    0.331465  0.300115  1.000000  0.439902  0.558565  0.198240
# budget   0.209304 -0.005194  0.439902  1.000000  0.540326  0.176016
# gross    0.215943  0.089155  0.558565  0.540326  1.000000  0.175355
# runtime  0.097184  0.283611  0.198240  0.176016  0.175355  1.000000

# %%
df.corr(method ='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.099045  0.469829  0.291152  0.313716  0.142977
# score    0.099045  1.000000  0.428138 -0.007500  0.130397  0.399857
# votes    0.469829  0.428138  1.000000  0.604627  0.749942  0.290159
# budget   0.291152 -0.007500  0.604627  1.000000  0.714457  0.246748
# gross    0.313716  0.130397  0.749942  0.714457  1.000000  0.254471
# runtime  0.142977  0.399857  0.290159  0.246748  0.254471  1.000000

# %%
# Using Pearson method
# Can also use correlation_matrix = df.corr() to get same result

correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
# Using factorize - this assigns a random numeric value for each unique categorical value

df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000  0.143938  0.036367  0.965761  0.959015 -0.046733
# rating        0.143938  1.000000 -0.086723  0.156713  0.146606  0.012595
# genre         0.036367 -0.086723  1.000000  0.037184  0.035940 -0.002437
# year          0.965761  0.156713  0.037184  1.000000  0.993190 -0.044981
# released      0.959015  0.146606  0.035940  0.993190  1.000000 -0.045761
# score        -0.046733  0.012595 -0.002437 -0.044981 -0.045761  1.000000
# votes         0.287776  0.099972  0.023285  0.312401  0.299905 -0.009749
# director      0.745905  0.085520  0.047288  0.770497  0.770876 -0.022687
# writer        0.805211  0.103623  0.033688  0.824770  0.819617 -0.034685
# star          0.731565  0.093116  0.038649  0.756400  0.754468 -0.009896
# country       0.142828  0.000494 -0.015795  0.140216  0.148468  0.023097
# budget        0.275691  0.193229  0.069445  0.298022  0.284017 -0.011749
# ...

# %%
# Visualizing correlations using the matrix

correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
# Visualizing correlation using a list format which can be easier to read

correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# name          name            1.000000
#               rating          0.143938
#               genre           0.036367
#               year            0.965761
#               released        0.959015
#               score          -0.046733
#               votes           0.287776
#               director        0.745905
#               writer          0.805211
#               star            0.731565
#               country         0.142828
#               budget          0.275691
#               gross           0.947192
#               company         0.591667
#               runtime         0.048955
#               year_correct    0.822322
# rating        name            0.143938
#               rating          1.000000
#               genre          -0.086723
#               year            0.156713
#               released        0.146606
#               score           0.012595
#               votes           0.099972
#               director        0.085520
# ...

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# company       budget         -0.087285
# budget        company        -0.087285
# genre         rating         -0.086723
# rating        genre          -0.086723
# country       budget         -0.068884
# budget        country        -0.068884
# score         gross          -0.046835
# gross         score          -0.046835
# score         name           -0.046733
# name          score          -0.046733
# country       votes          -0.045914
# votes         country        -0.045914
# score         released       -0.045761
# released      score          -0.045761
# score         year           -0.044981
# year          score          -0.044981
# year_correct  score          -0.040775
# score         year_correct   -0.040775
# writer        score          -0.034685
# score         writer         -0.034685
# company       score          -0.028432
# score         company        -0.028432
# company       rating         -0.028035
# rating        company        -0.028035
# ...

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# star          company         0.527116
# company       star            0.527116
# writer        company         0.546151
# company       writer          0.546151
#               director        0.552258
# director      company         0.552258
# gross         company         0.588216
# company       gross           0.588216
# name          company         0.591667
# company       name            0.591667
#               year            0.601571
# year          company         0.601571
# released      company         0.607954
# company       released        0.607954
# star          year_correct    0.637549
# year_correct  star            0.637549
# director      year_correct    0.641746
# year_correct  director        0.641746
# star          writer          0.675685
# writer        star            0.675685
# star          director        0.682385
# director      star            0.682385
# year_correct  writer          0.707036
# writer        year_correct    0.707036
# ...

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 56491421806
# Universal Pictures           52514188890
# Columbia Pictures            43008941346
# Paramount Pictures           40493607415
# Walt Disney Pictures         36327887792
# Twentieth Century Fox        30913193094
# New Line Cinema              19883797684
# DreamWorks Animation         11873612858
# Touchstone Pictures          11795832638
# Dreamworks Pictures          11635441081
# Marvel Studios               10120607435
# Metro-Goldwyn-Mayer (MGM)     9230230105
# Summit Entertainment          8373718838
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7443502667
# Name: gross, dtype: int64

# %%
df['Year'] = df['released'].astype(str).str[:4]
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# 5                                    Friday the 13th          R     Horror
# 6                                 The Blues Brothers          R     Action
# 7                                        Raging Bull          R  Biography
# 8                                        Superman II         PG     Action
# 9                                    The Long Riders          R  Biography
# 10                             Any Which Way You Can         PG     Action
# ...

# %%
df.groupby(['company', 'year'])[["gross"]].sum()
# Out:
#                                                  gross
# company                              year
# "DIA" Productions GmbH & Co. KG      2003   44350926.0
# "Weathering With You" Film Partners  2019  193457467.0
# .406 Production                      1996      10580.0
# 1+2 Seisaku Iinkai                   2000    1196218.0
# 10 West Studios                      2010     814906.0
# 120 Films                            2002    6479328.0
# 120dB Films                          2009      26676.0
#                                      2016     368372.0
# 13 Productions                       2000      25461.0
# 1492 Pictures                        1996  129832389.0
#                                      1999   87423861.0
# 1818 Productions                     1983   12232628.0
# 19 Entertainment                     2003    4928883.0
# 1978 Films                           2017   40656399.0
# 1984 Private Defense Contractors     2014   58834384.0
# ...

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company               year
# Walt Disney Pictures  2019    5773131804
# Marvel Studios        2018    4018631866
# Universal Pictures    2015    3834354888
# Walt Disney Pictures  2017    3789382071
# Paramount Pictures    2011    3565705182
# Warner Bros.          2010    3300479986
#                       2011    3223799224
# Walt Disney Pictures  2010    3104474158
# Paramount Pictures    2014    3071298586
# Columbia Pictures     2006    2934631933
#                       2019    2932757449
# Warner Bros.          2018    2774168962
# Columbia Pictures     2011    2738363306
# Warner Bros.          2005    2688767210
#                       2004    2662920386
# Name: gross, dtype: int64

# %%
# looking at the correlation between budget and gross revenue

plt.scatter(x=df['budget'], y=df['gross'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df_numerized = df


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 0     6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1     5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2     5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3      286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4     1027       6      4  1980      1543    7.3   108000.0      1054     521
# 5     2109       6     10  1980      2502    6.4   123000.0      2528    4362
# 6     5574       6      0  1980      1771    7.9   188000.0      1412     838
# 7     4436       6      3  1980       699    8.2   330000.0      1829    1769
# 8     5281       4      0  1980      1753    6.8   101000.0      2306    1979
# 9     6213       6      3  1980      2286    7.0    10000.0      2864     423
# 10     463       4      0  1980       674    6.1    18000.0       357    3985
# ...

# %%
df_numerized.corr(method='pearson')
# Out:
#                   name    rating     genre      year  released     score  \
# name          1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating       -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre         0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year          0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released     -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score         0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes         0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director      0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer        0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star          0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country      -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget        0.020548 -0.081939 -0.334021  0.309212  0.009145  0.055665
# ...

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
for col_name in df.columns:
    if(df[col_name].dtype == 'object'):
        df[col_name]= df[col_name].astype('category')
        df[col_name] = df[col_name].cat.codes
